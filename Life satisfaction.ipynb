# %%
def prepare_country_stats(oecd_bli, gdp_per_capita):
    oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
    oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
    gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
    gdp_per_capita.set_index("Country", inplace=True)
    full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
                                  left_index=True, right_index=True)
    full_country_stats.sort_values(by="GDP per capita", inplace=True)
    remove_indices = [0, 1, 6, 8, 33, 34, 35]
    keep_indices = list(set(range(36)) - set(remove_indices))
    return full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]

# %%
import os

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# %%
#Read the data
oecd_bli = pd.read_csv("./oecd_bli_2015.csv", thousands=',')

# %%
gdp_per_capita = pd.read_csv("./gdp_per_capita.csv",thousands=',',delimiter='\t',
                             encoding='latin1', na_values="n/a")

# %%
#Prepare the data
country_stats = prepare_country_stats(oecd_bli, gdp_per_capita)
X = np.c_[country_stats["GDP per capita"]]
y = np.c_[country_stats["Life satisfaction"]]

# %%
#Visualize the data
ax = country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
ax.set(xlabel="GDP per capita", ylabel="Life satisfaction")
plt.show()

# %%
#Linear Model
model=sklearn.linear_model.LinearRegression()

# %%
#Training Model
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Predict Cyprus
X_new=[[22587]] #Cyprus GDP per capita
print(model.predict(X_new))
# Out:
# [[5.96242338]]

# %%
#Replace Linear model to KNN Model
import sklearn.neighbors
knn=sklearn.neighbors.KNeighborsRegressor(n_neighbors=3)

# %%
#Training Model
knn.fit(X,y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform')

# %%
#Predict Cyprus
print(knn.predict(X_new))
# Out:
# [[5.76666667]]

# %%
#Read the Life satisfaction data
oecd_bli = pd.read_csv("./oecd_bli_2015.csv", thousands=',')
oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
oecd_bli.head(2)
# Out:
# Indicator  Air pollution  Assault rate  Consultation on rule-making  \
# Country
# Australia           13.0           2.1                         10.5
# Austria             27.0           3.4                          7.1
#
# Indicator  Dwellings without basic facilities  Educational attainment  \
# Country
# Australia                                 1.1                    76.0
# Austria                                   1.0                    83.0
#
# Indicator  Employees working very long hours  Employment rate  Homicide rate  \
# Country
# Australia                              14.02             72.0            0.8
# Austria                                 7.61             72.0            0.4
#
# Indicator  Household net adjusted disposable income  \
# Country
# Australia                                   31588.0
# Austria                                     31173.0
#
# Indicator  Household net financial wealth  ...  Long-term unemployment rate  \
# ...

# %%
oecd_bli['Life satisfaction'].head()
# Out:
# Country
# Australia    7.3
# Austria      6.9
# Belgium      6.9
# Brazil       7.0
# Canada       7.3
# Name: Life satisfaction, dtype: float64

# %%
#Read the GDP per capita data
gdp_per_capita = pd.read_csv("./gdp_per_capita.csv", thousands=',', delimiter='\t',
                             encoding='latin1', na_values="n/a")
gdp_per_capita.rename(columns={"2015": "GDP per capita"},inplace=True)  
gdp_per_capita.set_index('Country',inplace=True)
gdp_per_capita.head(2)
# Out:
#                                             Subject Descriptor         Units  \
# Country
# Afghanistan  Gross domestic product per capita, current prices  U.S. dollars
# Albania      Gross domestic product per capita, current prices  U.S. dollars
#
#              Scale                      Country/Series-specific Notes  \
# Country
# Afghanistan  Units  See notes for:  Gross domestic product, curren...
# Albania      Units  See notes for:  Gross domestic product, curren...
#
#              GDP per capita  Estimates Start After
# Country
# Afghanistan         599.994                 2013.0
# Albania            3995.383                 2010.0

# %%
full_country_stats=pd.merge(left=oecd_bli, right=gdp_per_capita, left_index=True,
right_index=True)
full_country_stats.sort_values(by='GDP per capita',inplace=True)
full_country_stats
# Out:
#                      3.58             69.0
# Canada                                        3.94             72.0
# Netherlands                                   0.45             74.0
# Austria                                       7.61             72.0
# United Kingdom                               12.70             71.0
# Sweden                                        1.13             74.0
# Iceland                                      12.25             82.0
# Australia                                    14.02             72.0
# Ireland                                       4.20             60.0
# Denmark                                       2.03             73.0
# United States                                11.30             67.0
# Norway                                        2.82             75.0
# Switzerland                                   6.72             80.0
# Luxembourg                                    3.47             66.0
#
# ...

# %%
full_country_stats[['GDP per capita','Life satisfaction']].loc['Korea']
# Out:
# GDP per capita       27195.197
# Life satisfaction        5.800
# Name: Korea, dtype: float64

# %%
remove_indices=[0, 1, 6, 8, 33, 34, 35]
keep_indices = list(set(range(36))-set(remove_indices))

sample_data=full_country_stats[['GDP per capita','Life satisfaction']].iloc[keep_indices]
missing_data=full_country_stats[['GDP per capita','Life satisfaction']].iloc[remove_indices]

# %%
#Plot
ax = sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3))
ax.set(xlabel='GDP per capita', ylabel='Life satisfaction')
plt.axis([0, 60000, 0, 10])
position_text = {
    "Spain": (5000, 1, 'Spain'),
    "Korea": (18000, 1.7, 'Korea'),
    "France": (29000, 2.4, 'France'),
    "Japan": (40000, 3.0, 'Japan'),
    "United States": (52000, 3.8, 'United States'),
}
for country, pos_text in position_text.items():
    pos_data_x, pos_data_y = sample_data.loc[country]
    country = "U.S." if country == "United States" else country
    plt.annotate(pos_text[2], xy=(pos_data_x, pos_data_y), xytext=pos_text[:2],
            arrowprops=dict(facecolor='black', width=0.5, shrink=0.1, headwidth=5))
    plt.plot(pos_data_x, pos_data_y, "ro")
plt.show()

# %%
sample_data.to_csv("./lifesat.csv")

# %%
sample_data.loc[list(position_text.keys())]
# Out:
#                GDP per capita  Life satisfaction
# Country
# Spain               25864.721                6.5
# Korea               27195.197                5.8
# France              37675.006                6.5
# Japan               32485.545                5.9
# United States       55805.204                7.2

# %%
ax = sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3))
ax.set(xlabel='GDP per capita', ylabel='Life satisfaction')
plt.axis([0, 60000, 0, 10])
X=np.linspace(0, 60000, 1000)
plt.plot(X, 2*X/100000, "r")
plt.text(40000, 2.7, r"$\theta_0 = 0$", fontsize=14, color="r")
plt.text(40000, 1.8, r"$\theta_1 = 2 \times 10^{-5}$", fontsize=14, color="r")
plt.plot(X, 8 - 5*X/100000, "g")
plt.text(5000, 9.1, r"$\theta_0 = 8$", fontsize=14, color="g")
plt.text(5000, 8.2, r"$\theta_1 = -5 \times 10^{-5}$", fontsize=14, color="g")
plt.plot(X, 4 + 5*X/100000, "b")
plt.text(5000, 3.5, r"$\theta_0 = 4$", fontsize=14, color="b")
plt.text(5000, 2.6, r"$\theta_1 = 5 \times 10^{-5}$", fontsize=14, color="b")
plt.show()

# %%
from sklearn import linear_model
lin1 = linear_model.LinearRegression()
Xsample = np.c_[sample_data['GDP per capita']]
ysample = np.c_[sample_data['Life satisfaction']]
lin1.fit(Xsample, ysample)
t0, t1 = lin1.intercept_[0], lin1.coef_[0][0]
t0, t1
# Out:
# (4.853052800266436, 4.911544589158484e-05)

# %%
ax = sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3))
ax.set(xlabel='GDP per capita', ylabel='Life satisfaction')
plt.axis([0, 60000, 0, 10])
X=np.linspace(0, 60000, 1000)
plt.plot(X, t0 + t1*X, "b")
plt.text(5000, 3.1, r"$\theta_0 = 4.85$", fontsize=14, color="b")
plt.text(5000, 2.2, r"$\theta_1 = 4.91 \times 10^{-5}$", fontsize=14, color="b")
plt.show()

# %%
#Korea Life Satisfaction by GDP
korea_gdp_per_capita = gdp_per_capita.loc["Korea"]["GDP per capita"]
print(korea_gdp_per_capita)
korea_predicted_life_satisfaction = lin1.predict(korea_gdp_per_capita.reshape(-1,1))[0][0]
korea_predicted_life_satisfaction
# Out:
# 27195.197
# 6.188757027030927

# %%
ax = sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3), s=1)
ax.set(xlabel='GDP per capita', ylabel='Life satisfaction')
X=np.linspace(0, 60000, 1000)
plt.plot(X, t0 + t1*X, "b")
plt.axis([0, 60000, 0, 10])
plt.text(5000, 7.5, r"$\theta_0 = 4.85$", fontsize=14, color="b")
plt.text(5000, 6.6, r"$\theta_1 = 4.91 \times 10^{-5}$", fontsize=14, color="b")
plt.plot([korea_gdp_per_capita, korea_gdp_per_capita], [0, korea_predicted_life_satisfaction], "r--")
plt.text(25000, 5.0, r"predict = 5.96", fontsize=14, color="b")
plt.plot(korea_gdp_per_capita, korea_predicted_life_satisfaction, "ro")
plt.show()

# %%
sample_data[7:10]
# Out:
#           GDP per capita  Life satisfaction
# Country
# Portugal       19121.592                5.1
# Slovenia       20732.482                5.7
# Spain          25864.721                6.5

# %%
missing_data
# Out:
#                 GDP per capita  Life satisfaction
# Country
# Brazil                8669.998                7.0
# Mexico                9009.280                6.7
# Chile                13340.905                6.7
# Czech Republic       17256.918                6.5
# Norway               74822.106                7.4
# Switzerland          80675.308                7.5
# Luxembourg          101994.093                6.9

# %%
position_text2 = {
    "Brazil": (1000, 9.0, 'Brazil'),
    "Mexico": (11000, 9.0, 'Mexico'),
    "Chile": (25000, 9.0, 'Chile'),
    "Czech Republic": (35000, 9.0, 'Czech Republic'),
    "Norway": (60000, 3, 'Norway'),
    "Switzerland": (72000, 3.0, 'Switzerland'),
    "Luxembourg": (90000, 3.0, 'Luxembourg'),
}

# %%
ax = sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(8,3))
ax.set(xlabel='GDP per capita', ylabel='Life satisfaction')
plt.axis([0, 110000, 0, 10])

for country, pos_text in position_text2.items():
    pos_data_x, pos_data_y = missing_data.loc[country]
    plt.annotate(pos_text[2], xy=(pos_data_x, pos_data_y), xytext=pos_text[:2],
            arrowprops=dict(facecolor='black', width=0.5, shrink=0.1, headwidth=5))
    plt.plot(pos_data_x, pos_data_y, "rs")

X=np.linspace(0, 110000, 1000)
plt.plot(X, t0 + t1*X, "b:")

lin_reg_full = linear_model.LinearRegression()
Xfull = np.c_[full_country_stats["GDP per capita"]]
yfull = np.c_[full_country_stats["Life satisfaction"]]
lin_reg_full.fit(Xfull, yfull)

t0full, t1full = lin_reg_full.intercept_[0], lin_reg_full.coef_[0][0]
X = np.linspace(0, 110000, 1000)
plt.plot(X, t0full + t1full * X, "k")

plt.show()

# %%
#Overfitting
ax = full_country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(8,3))
ax.set(xlabel='GDP per capita', ylabel='Life satisfaction')
plt.axis([0, 110000, 0, 10])

from sklearn import preprocessing
from sklearn import pipeline

poly = preprocessing.PolynomialFeatures(degree=60, include_bias=False)
scaler = preprocessing.StandardScaler()
lin_reg2 = linear_model.LinearRegression()

pipeline_reg = pipeline.Pipeline([('poly', poly), ('scal', scaler), ('lin', lin_reg2)])
pipeline_reg.fit(Xfull, yfull)
curve = pipeline_reg.predict(X[:, np.newaxis])
plt.plot(X, curve)
plt.show()

# %%
#Is country where has 'w' higher life satisfaction than non 'w'?
full_country_stats.loc[[c for c in full_country_stats.index if "W" in c.upper()]]["Life satisfaction"]
# Out:
# Country
# New Zealand    7.3
# Sweden         7.2
# Norway         7.4
# Switzerland    7.5
# Name: Life satisfaction, dtype: float64

# %%
gdp_per_capita.loc[[c for c in gdp_per_capita.index if "W" in c.upper()]].head()
# Out:
#                                             Subject Descriptor         Units  \
# Country
# Botswana     Gross domestic product per capita, current prices  U.S. dollars
# Kuwait       Gross domestic product per capita, current prices  U.S. dollars
# Malawi       Gross domestic product per capita, current prices  U.S. dollars
# New Zealand  Gross domestic product per capita, current prices  U.S. dollars
# Norway       Gross domestic product per capita, current prices  U.S. dollars
#
#              Scale                      Country/Series-specific Notes  \
# Country
# Botswana     Units  See notes for:  Gross domestic product, curren...
# Kuwait       Units  See notes for:  Gross domestic product, curren...
# Malawi       Units  See notes for:  Gross domestic product, curren...
# New Zealand  Units  See notes for:  Gross domestic product, curren...
# Norway       Units  See notes for:  Gross domestic product, curren...
#
#              GDP per capita  Estimates Start After
# Country
# ...

# %%
plt.figure(figsize=(8,3))

plt.xlabel("GDP per capita")
plt.ylabel('Life satisfaction')

plt.plot(list(sample_data["GDP per capita"]), list(sample_data["Life satisfaction"]), "bo")
plt.plot(list(missing_data["GDP per capita"]), list(missing_data["Life satisfaction"]), "rs")

X = np.linspace(0, 110000, 1000)
plt.plot(X, t0full + t1full * X, "r--", label="Linear Model by all data")
plt.plot(X, t0 + t1*X, "b:", label="Linear Model by some data")

ridge = linear_model.Ridge(alpha=10**9.5)
Xsample = np.c_[sample_data["GDP per capita"]]
ysample = np.c_[sample_data["Life satisfaction"]]
ridge.fit(Xsample, ysample)
t0ridge, t1ridge = ridge.intercept_[0], ridge.coef_[0][0]
plt.plot(X, t0ridge + t1ridge * X, "b", label="Linear Model applied regularization by some data")

plt.legend(loc="lower right")
plt.axis([0, 110000, 0, 10])
plt.show()
